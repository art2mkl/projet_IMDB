# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from scraping import Dbase
import numpy as np
import warnings
import pandas as pd
warnings.filterwarnings('ignore')
plt.style.use('fivethirtyeight')

# %%
data = Dbase()
df1 = data.imdb_requests()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   titles         250 non-null    object
#  1   genre1         250 non-null    object
#  2   genre2         250 non-null    object
#  3   genre3         250 non-null    object
#  4   nb_genres      250 non-null    int64
#  5   released_year  250 non-null    int64
#  6   director1      250 non-null    object
#  7   director2      250 non-null    object
#  8   director3      250 non-null    object
#  9   nb_directors   250 non-null    int64
#  10  grade          250 non-null    float64
#  11  votes          250 non-null    int64
#  12  gross(M$)      250 non-null    float64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 25.5+ KB

# %% [markdown]
# # Objectif : Prédiction de la note

# %%
#!pip install pandas_profiling

# %%
df1
# Out:
#                                   titles     genre1     genre2   genre3  \
# 0                             Les Évadés      Drama      Drama    Drama
# 1                             Le parrain      Crime      Drama    Drama
# 2    The Dark Knight : Le Chevalier noir     Action      Crime    Drama
# 3                Le parrain, 2ème partie      Crime      Drama    Drama
# 4                    12 Hommes en colère      Crime      Drama    Drama
# ..                                   ...        ...        ...      ...
# 245                   Mr. Smith au sénat     Comedy      Drama    Drama
# 246            Autant en emporte le vent      Drama    History  Romance
# 247                     New York - Miami     Comedy    Romance  Romance
# 248           La passion de Jeanne d'Arc  Biography      Drama  History
# 249             Le mécano de la Générale     Action  Adventure   Comedy
#
#      nb_genres  released_year             director1             director2  \
# 0            1           1994        Frank Darabont        Frank Darabont
# 1            2           1972  Francis Ford Coppola  Francis Ford Coppola
# 2            3           2008     Christopher Nolan     Christopher Nolan
# 3            2           1974  Francis Ford Coppola  Francis Ford Coppola
# 4            2           1957          Sidney Lumet          Sidney Lumet
# ..         ...            ...                   ...                   ...
# 245          2           1939           Frank Capra           Frank Capra
# 246          3           1939        Victor Fleming          George Cukor
# 247          2           1934           Frank Capra           Frank Capra
# 248          3           1928   Carl Theodor Dreyer   Carl Theodor Dreyer
# 249          3           1926        Clyde Bruckman         Buster Keaton
#
#                 director3  nb_directors  grade    votes  gross(M$)
# 0          Frank Darabont             1    9.3  2386840      28.34
# 1    Francis Ford Coppola             1    9.2  1654244     134.97
# 2       Christopher Nolan             1    9.0  2349926     534.86
# 3    Francis Ford Coppola             1    9.0  1150704      57.30
# 4            Sidney Lumet             1    9.0   704580       4.36
# ..                    ...           ...    ...      ...        ...
# 245           Frank Capra             1    8.1   108524       9.60
# 246              Sam Wood             3    8.1   294171     198.68
# 247           Frank Capra             1    8.1    95817       4.36
# 248   Carl Theodor Dreyer             1    8.1    49030       0.02
# 249         Buster Keaton             2    8.1    82628       1.03
#
# [250 rows x 13 columns]

# %% [markdown]
# ## Observation

# %%
from pandas_profiling import ProfileReport
prof = ProfileReport(df1.sample(n=250))
prof.to_file(output_file='output.html')
# Out:
# HBox(children=(HTML(value='Summarize dataset'), FloatProgress(value=0.0, max=27.0), HTML(value='')))
# HBox(children=(HTML(value='Generate report structure'), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(HTML(value='Render HTML'), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(HTML(value='Export report to file'), FloatProgress(value=0.0, max=1.0), HTML(value='')))

# %%
df1.plot()
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df1)

# %% [markdown]
# ## Numerical variables

# %%
# Variable grade : Target

# %%
df2 = pd.DataFrame()
df2['pearson'] = abs(df1.corr(method = 'pearson'))['grade']

# %%
df2['spearman'] = abs(df1.corr(method = 'spearman'))['grade']

# %%
df2['kendall'] = abs(df1.corr(method = 'kendall'))['grade']

# %%
df2
# Out:
#                 pearson  spearman   kendall
# nb_genres      0.082737  0.045144  0.038321
# released_year  0.008833  0.036930  0.026655
# nb_directors   0.057689  0.049722  0.043854
# grade          1.000000  1.000000  1.000000
# votes          0.605702  0.391127  0.289274
# gross(M$)      0.201002  0.128392  0.092614

# %% [markdown]
# * **Par rapport au model prédictif, Seul 'votes' bénéficie d'une corrélation intéressante**

# %%
# Distribution de la variable grade:

# %%
sns.histplot(x='grade', data=df1)
# Out:
# <AxesSubplot:xlabel='grade', ylabel='Count'>

# %%
df1['grade'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
import statsmodels.api as sm
plt.figure(figsize=(15,7))
sm.qqplot(df1['grade'], line = 'r')
plt.show()

# %% [markdown]
# ![f9ce6849-b645-490f-b20b-2d0c11c23f93.jpg](attachment:f9ce6849-b645-490f-b20b-2d0c11c23f93.jpg)

# %% [markdown]
# ![800bd468-d716-457a-9b23-9900ced88183.jpg](attachment:800bd468-d716-457a-9b23-9900ced88183.jpg)

# %%
# variable vote:

# %%
df1['votes'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
plt.figure(figsize=(15,7))
sm.qqplot(df1['votes'], line = 'r')
plt.show()

# %%
#JointGrid 
g = sns.JointGrid (x = "votes", y = "grade", data = df1)
g = g.plot (sns.regplot, sns.distplot)

# %%
#Ordinary Least Squares (OLS) Regression
import statsmodels.api as sm # Ordinary Least Squares (OLS) Regression and some other
results = sm.OLS(df1['votes'], df1['grade']).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  votes   R-squared (uncentered):                   0.588
# Model:                            OLS   Adj. R-squared (uncentered):              0.586
# Method:                 Least Squares   F-statistic:                              355.0
# Date:                Mon, 10 May 2021   Prob (F-statistic):                    8.12e-50
# Time:                        15:07:01   Log-Likelihood:                         -3617.6
# No. Observations:                 250   AIC:                                      7237.
# Df Residuals:                     249   BIC:                                      7241.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# grade       6.695e+04   3553.576     18.840      0.000       6e+04    7.39e+04
# ==============================================================================
# Omnibus:                       49.127   Durbin-Watson:                   0.811
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               73.534
# Skew:                           1.175   Prob(JB):                     1.08e-16
# Kurtosis:                       4.241   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#comparaison des distributions avec un boxplot
plt.figure(figsize=(15,7))
ax = sns.boxplot(x='nb_directors', y='grade', data =df1)
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2]), [Text(0, 0, '1'), Text(1, 0, '2'), Text(2, 0, '3')])

# %%
#comparaison des distributions avec un boxplot
plt.figure(figsize=(15,7))
ax = sns.boxplot(x='nb_genres', y='grade', data =df1)
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2]), [Text(0, 0, '1'), Text(1, 0, '2'), Text(2, 0, '3')])

# %%
# Analyse Top votes:

# %%
top_votes = df1[['titles','votes','grade','genre1','director1']].sort_values(by ='votes', ascending = False)

# %%
top_votes
# Out:
#                                   titles    votes  grade  genre1  \
# 0                             Les Évadés  2386840    9.3   Drama
# 2    The Dark Knight : Le Chevalier noir  2349926    9.0  Action
# 8                              Inception  2108336    8.8  Action
# 9                             Fight Club  1888071    8.8   Drama
# 6                           Pulp Fiction  1858799    8.9   Crime
# ..                                   ...      ...    ...     ...
# 171                       Jeux dangereux    31388    8.2  Comedy
# 240            Du rififi chez les hommes    30348    8.1   Crime
# 155                     Sonate d'automne    28643    8.2   Drama
# 149                  Le temps des gitans    28127    8.2  Comedy
# 32                              Ratsasan    28104    8.5  Action
#
#              director1
# 0       Frank Darabont
# 2    Christopher Nolan
# 8    Christopher Nolan
# 9        David Fincher
# 6    Quentin Tarantino
# ..                 ...
# 171     Ernst Lubitsch
# 240       Jules Dassin
# 155     Ingmar Bergman
# 149     Emir Kusturica
# 32           Ram Kumar
#
# [250 rows x 5 columns]

# %%
top_10_votes = top_votes[:10]

plt.figure(figsize=(15,9))
sns.set_theme(style="whitegrid")
ax = sns.barplot(x='grade', y="titles", data=top_10_votes, hue="votes", palette='coolwarm')

# %%
#####

# %% [markdown]
# Challenges
# ** What was the highest scoring movie in 2020?
# ** In what year was the highest rated movie of all time made?
# ** What five movies have the most votes ever?

# %%
#What was the highest scoring movie in 2020?

# %%
df_year_2020 = df1[df1['released_year'] == 2020].sort_values(by='grade', ascending=False).head()

# %%
df_year_2020
# Out:
#          titles     genre1     genre2   genre3  nb_genres  released_year  \
# 31     Hamilton  Biography      Drama  History          3           2020
# 86   The Father      Drama      Drama    Drama          1           2020
# 181        Soul  Animation  Adventure   Comedy          3           2020
#
#           director1       director2       director3  nb_directors  grade  \
# 31      Thomas Kail     Thomas Kail     Thomas Kail             1    8.5
# 86   Florian Zeller  Florian Zeller  Florian Zeller             1    8.3
# 181     Pete Docter     Kemp Powers     Kemp Powers             2    8.1
#
#       votes   gross(M$)
# 31    63736  254.633333
# 86    52820  254.633333
# 181  235642  254.633333

# %%
plt.figure(figsize=(15,7))
ax = sns.countplot(x="votes", hue="titles", data=df_year_2020)

# %%
# In what year was the highest rated movie of all time made?

# %%
year_highest_rated_movie = df1[df1['grade'] == df1['grade'].max()]
year_highest_rated_movie
# Out:
#        titles genre1 genre2 genre3  nb_genres  released_year       director1  \
# 0  Les Évadés  Drama  Drama  Drama          1           1994  Frank Darabont
#
#         director2       director3  nb_directors  grade    votes  gross(M$)
# 0  Frank Darabont  Frank Darabont             1    9.3  2386840      28.34

# %%
# What five movies have the most votes ever?

# %%
df_sorted_by_votes = df1.sort_values(by='votes', ascending=False).head()
df_sorted_by_votes
# Out:
#                                 titles  genre1     genre2  genre3  nb_genres  \
# 0                           Les Évadés   Drama      Drama   Drama          1
# 2  The Dark Knight : Le Chevalier noir  Action      Crime   Drama          3
# 8                            Inception  Action  Adventure  Sci-Fi          3
# 9                           Fight Club   Drama      Drama   Drama          1
# 6                         Pulp Fiction   Crime      Drama   Drama          2
#
#    released_year          director1          director2          director3  \
# 0           1994     Frank Darabont     Frank Darabont     Frank Darabont
# 2           2008  Christopher Nolan  Christopher Nolan  Christopher Nolan
# 8           2010  Christopher Nolan  Christopher Nolan  Christopher Nolan
# 9           1999      David Fincher      David Fincher      David Fincher
# 6           1994  Quentin Tarantino  Quentin Tarantino  Quentin Tarantino
#
#    nb_directors  grade    votes  gross(M$)
# 0             1    9.3  2386840      28.34
# 2             1    9.0  2349926     534.86
# 8             1    8.8  2108336     292.58
# 9             1    8.8  1888071      37.03
# 6             1    8.9  1858799     107.93

# %%
####

# %% [markdown]
# ## Categorial variables

# %%
df_cat = df1[['genre1','director1']]
df_cat
# Out:
#         genre1             director1
# 0        Drama        Frank Darabont
# 1        Crime  Francis Ford Coppola
# 2       Action     Christopher Nolan
# 3        Crime  Francis Ford Coppola
# 4        Crime          Sidney Lumet
# ..         ...                   ...
# 245     Comedy           Frank Capra
# 246      Drama        Victor Fleming
# 247     Comedy           Frank Capra
# 248  Biography   Carl Theodor Dreyer
# 249     Action        Clyde Bruckman
#
# [250 rows x 2 columns]

# %%
#df_cat2 = pd.DataFrame(df1, columns = ['genre1', 'director1'])
#df_cat2

# %%
ax = sns.boxplot(x="genre1", y="grade", data=df1)
plt.xticks(rotation=45)
sns.set(rc={'figure.figsize':(30, 10)})

# %%
top_20_votes = top_votes[:20]

plt.figure(figsize=(15,7))
sns.countplot(data=top_20_votes, x='genre1')
# Out:
# <AxesSubplot:xlabel='genre1', ylabel='count'>

# %%
top_50_votes = top_votes[:50]

# %%
plt.figure(figsize=(15,7))
sns.countplot(data=top_50_votes, x='genre1')
# Out:
# <AxesSubplot:xlabel='genre1', ylabel='count'>

# %%
plt.figure(figsize=(15,7))
sns.countplot(data=top_50_votes, order=top_50_votes['director1'].value_counts().index , y='director1')
# Out:
# <AxesSubplot:xlabel='count', ylabel='director1'>

# %%
from matplotlib.pyplot import figure
ax = sns.boxplot(x="director1", y="grade", data=df1)
plt.xticks(rotation=45)
sns.set(rc={'figure.figsize':(30, 10)})

# %%
df1['director1'].value_counts()
# Out:
# Stanley Kubrick      7
# Christopher Nolan    7
# Martin Scorsese      7
# Alfred Hitchcock     6
# Akira Kurosawa       6
#                     ..
# Wes Anderson         1
# Carol Reed           1
# Kar-Wai Wong         1
# Thomas Kail          1
# Terry George         1
# Name: director1, Length: 157, dtype: int64

# %%
df1['director1'].nunique()
# Out:
# 157

# %%
df4 = df1.head(25)

# %%
sns.boxplot(x="director1", y="grade", data=df4)
# Out:
# <AxesSubplot:xlabel='director1', ylabel='grade'>

# %%
df1[df1['director1']=='Frank Darabont']

# %%
df5 = df1[:100].copy()

# %%
df6 = pd.get_dummies(data=df5, columns=['director1','genre1'])

# %%
df6

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import MaxAbsScaler
scaler = MinMaxScaler()
keepCols = ['votes']
scaled_df = scaler.fit_transform(df6[keepCols])
scaled_df = pd.DataFrame(scaled_df, columns=keepCols)

scaled_df

# %%
df6['votes'] = scaled_df

# %% [markdown]
# # NECESSITE DE SCALER LES DONNES NUMERIQUES

# %%
#importer les données Advertising.csv
list_var = df6.drop(['titles','genre2','genre3','nb_genres','released_year','director2','director3','nb_directors','grade','gross(M$)'],axis = 1)
list_var

# %%
from sklearn.linear_model import LinearRegression

#créer un objet reg lin
modeleReg=LinearRegression()

y=df6['grade']
X=list_var

modeleReg.fit(X,y)

# %%
print(f'La constante est égale à : {modeleReg.intercept_}')
print(f'Les coefficients directeurs sont respectivement de : {modeleReg.coef_}')

#calcul du R²
Rcarre = modeleReg.score(X,y)
print(f'le R² est de : {Rcarre}')

RMSE=np.sqrt(((y-modeleReg.predict(X))**2).sum()/len(y))
print(f'La RMSE est de : {RMSE}')

# %%
plt.plot(y, modeleReg.predict(X),'.')
plt.show()

# %%
plt.plot(y, y-modeleReg.predict(X),'.')
plt.show()

# %%
from sklearn.metrics import mean_squared_error

# %%
def prepare_machine(df):
    df = pd.get_dummies(data=df, columns=['director1', 'genre1'])
    scaler = MinMaxScaler()
    keepCols = ['votes']
    scaled_df = scaler.fit_transform(df[keepCols])
    scaled_df = pd.DataFrame(scaled_df, columns=keepCols)
    df['votes'] = scaled_df
    df = df.drop(['genre2', 'genre3', 'nb_genres', 'released_year',
                  'director2', 'director3', 'nb_directors', 'gross(M$)'], axis=1)
    return df

# %%
def create_model(df):
    df = prepare_machine(df)
    df = df.iloc[np.random.permutation(df.index)].reset_index(drop=True)
    
    cut = round(len(df)*0.995)
    train = df
    #train = df.iloc[:cut,:]
    #test = df[50:59]
    test = df.iloc[cut:,:]
    
    y = train['grade']
    X = train.drop(['titles','grade'],axis = 1)
      
    model=LinearRegression()
    model.fit(X,y)
    Rcarre = model.score(X,y)
    
    y = test['grade']
    nom = test['titles'].iloc[0]
    X = test.drop(['titles','grade'],axis = 1)
      
    prediction = model.predict(X)
    
    #RMSE=np.sqrt(((y-prediction)**2).sum()/len(y))
    rmse = mean_squared_error(prediction,y)**(1/2)
    return print(f"""
    Pour le film : {nom}, valeur attendue : {y.iloc[0]}, la prédiction est de {round(prediction[0],1)}
    R2 = {Rcarre}
    rmse = {rmse}
    """)

# %%
create_model(df1)

# %%
list(df1['director1'].value_counts().index)
list(df1['genre1'].value_counts().index)

# %%
df1[df1['genre1'] == 'Animation'].head()

# %%
from ipywidgets import interact
import ipywidgets as widgets

# %%
# Interact with specification of arguments
@interact
def affiche(titles='Ajouter_titre',
            director1=list(df1['director1'].value_counts().index),
            genre1=list(df1['genre1'].value_counts().index),
            votes = (0,1,0.1)
            ):
    df = prepare_machine(df1)
    df = df.iloc[np.random.permutation(df.index)].reset_index(drop=True)

    train = df

    test = train[0:1]
    a = test.iloc[:, 3:]
    for i in a:
        test[i] = 0
    test['titles'] = titles
    test['genre1_'+genre1] = 1
    test['director1_'+director1] = 1
    test['votes'] = votes

    y = train['grade']
    X = train.drop(['titles', 'grade'], axis=1)

    model = LinearRegression()
    model.fit(X, y)
    Rcarre = model.score(X, y)
    prediction = model.predict(X)
    rmse = mean_squared_error(prediction, y)**(1/2)
    
    nom = test['titles'].iloc[0]
    X = test.drop(['titles', 'grade'], axis=1)

    prediction = model.predict(X)
    if prediction < 0 or prediction > 10:
        prediction = ['impossible, ça ne sait pas faire ce genre de film']

    return f"""Le film : {nom} aura une note de : {prediction[0]}"""
